# %%
ls
# Out:
# README.md           bot/                utils.py
# Untitled.ipynb      fastapi-deployment/

# %%
# %%time

import os
import numpy as np
from glob import glob
import pandas as pd
from utils import async_requests
# Out:
# CPU times: user 854 ms, sys: 321 ms, total: 1.17 s
# Wall time: 2.75 s

# %%
 ../Downloads/archive/artDataset/
# Out:
# image_1.png    image_235.png  image_371.png  image_507.png  image_643.png
# image_10.png   image_236.png  image_372.png  image_508.png  image_644.png
# image_100.png  image_237.png  image_373.png  image_509.png  image_645.png
# image_101.png  image_238.png  image_374.png  image_51.png   image_646.png
# image_102.png  image_239.png  image_375.png  image_510.png  image_647.png
# image_103.png  image_24.png   image_376.png  image_511.png  image_648.png
# image_104.png  image_240.png  image_377.png  image_512.png  image_649.png
# image_105.png  image_241.png  image_378.png  image_513.png  image_65.png
# image_106.png  image_242.png  image_379.png  image_514.png  image_650.png
# image_107.png  image_243.png  image_38.png   image_515.png  image_651.png
# image_108.png  image_244.png  image_380.png  image_516.png  image_652.png
# image_109.png  image_245.png  image_381.png  image_517.png  image_653.png
# image_11.png   image_246.png  image_382.png  image_518.png  image_654.png
# ...

# %%
from pathlib import Path

# %%
path_files = Path("../Downloads/archive/artDataset")

# %%
all_files = list(path_files.rglob('*.png'))

# %%
all_files[0]
# Out:
# PosixPath('../Downloads/archive/artDataset/image_408.png')

# %%
# import tqdm_notebook
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 import tqdm_notebook
#
# ModuleNotFoundError: No module named 'tqdm_notebook'

# %%
os.path.abspath(all_files[0])
# Out:
# '/Users/ruavmi1/Downloads/archive/artDataset/image_408.png'

# %%
teams_y_pred = []
for i in all_files:
    preds = async_requests("https://art-expert-shadi.fly.dev/predict", os.path.abspath(i))
    teams_y_pred.append(preds)
    print(preds)
#     y_true.append(row.price)
# Out:
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# Process SpawnPoolWorker-640:
# Process SpawnPoolWorker-636:
# Process SpawnPoolWorker-772:
# Process SpawnPoolWorker-639:
# Process SpawnPoolWorker-637:
# Process SpawnPoolWorker-638:
# Process SpawnPoolWorker-766:
# Process SpawnPoolWorker-765:
# Process SpawnPoolWorker-767:
# Process SpawnPoolWorker-768:
# Process SpawnPoolWorker-770:
# Process SpawnPoolWorker-769:
# Process SpawnPoolWorker-771:
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
# Process SpawnPoolWorker-777:
# ...

# %%
teams_y_pred[0]

# %%
all_pred = []
for i in images:
    img_path = f"/kaggle/input/art-price-dataset/artDataset/image_{i}.png"
    preds =  requests("https://art-expert-shadi.fly.dev/predict", os.path.abspath(i))
    all_pred.append(preds)
